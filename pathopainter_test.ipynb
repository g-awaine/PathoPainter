# %% [markdown]
# # INIT

# %%
# !wget https://ommer-lab.com/files/latent-diffusion/vq-f4.zip
# !unzip vq-f4.zip

# %%
https://media.githubusercontent.com/media/mahmoodlab/HIPT/refs/heads/master/HIPT_4K/Checkpoints/vit256_small_dino.pth?download=true
https://ommer-lab.com/files/latent-diffusion/vq-f4.zip
https://drive.usercontent.google.com/download?id=1KMN5amIW9894VkXymTJzbkqZrCfWslSh&export=download&authuser=0&confirm=t&uuid=c6b84141-3942-4d89-8fd2-6e885365f6c8&at=AFYLz4MGUSVQt4_G45sDi_cDbks6:1785756908314

# %%
# %pip install -r requirements.txt
# Out:
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached accelerate-0.27.2-py3-none-any.whl.metadata (18 kB)
# ...
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ----- ---------------------------------- 1.0/7.4 MB 25.4 MB/s eta 0:00:01
#      -------------- ------------------------- 2.6/7.4 MB 6.0 MB/s eta 0:00:01
#      ---------------------------------------- 7.4/7.4 MB 12.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached albumentations-1.3.0-py3-none-any.whl.metadata (34 kB)
# ...
#   Using cached altair-5.1.1-py3-none-any.whl.metadata (8.6 kB)
# ...

# %%
# %pip install numpy omegaconf einops bitsandbytes taming-transformers pytorch-fid
# Out:
# ...
#   Using cached scipy-1.18.0-cp312-cp312-win_amd64.whl.metadata (61 kB)
# ...
# Using cached scipy-1.18.0-cp312-cp312-win_amd64.whl (36.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install "pytorch-lightning<2.0.0"
# Out:
# ...
#    ---------------------------------------- 0.0/829.5 kB ? eta -:--:--
#    --------------------------------------- 829.5/829.5 kB 18.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.6.5
#     Uninstalling pytorch-lightning-2.6.5:
#       Successfully uninstalled pytorch-lightning-2.6.5
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126

# %%
# !python main.py -t --gpus 0 --base configs/latent-diffusion/pathopainter.yaml
# Out:
# Running on GPUs 0
# ...
